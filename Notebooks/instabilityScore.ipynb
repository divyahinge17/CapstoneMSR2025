# %%
import pandas as pd
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# %%
file_path1 = './CSV/DependentsCounts.csv'
file_path2 = './CSV/DependenciesCountperArtifact.csv'
df_dependents = pd.read_csv(file_path1)
df_dependencies = pd.read_csv(file_path2)

# %%
df_dependents
# Out:
#                                      Artifact  DependentReleases  \
# 0                                 junit:junit            2775545
# 1                         org.slf4j:slf4j-api            1965315
# 2                    org.mockito:mockito-core            1716125
# 3                org.scala-lang:scala-library            1578767
# 4                    org.assertj:assertj-core            1098573
# ...                                       ...                ...
# 312791       org.webjars.npm:big-sparse-array                  1
# 312792     org.webjars.npm:quickbit-universal                  1
# 312793  org.webjars.npm:random-array-iterator                  1
# 312794          org.webjars.npm:crc-universal                  1
# 312795                      io.th0rgal:oraxen                  1
#
#         DependentArtifacts
# 0                   152993
# 1                    86288
# 2                    49097
# 3                    81074
# 4                    26342
# ...                    ...
# 312791                   1
# 312792                   1
# 312793                   1
# 312794                   1
# 312795                   1
#
# [312796 rows x 3 columns]

# %%
df_dependencies
# Out:
#                                                  Artifact  DependenciesCount
# 0          com.ibm.websphere.appserver.features:zosBundle               1337
# 1                           org.apache.camel:apache-camel               1323
# 2       com.ibm.websphere.appserver.features:ndMemberB...               1289
# 3         com.ibm.websphere.appserver.features:baseBundle               1286
# 4       com.ibm.websphere.appserver.features:libertyCo...               1021
# ...                                                   ...                ...
# 551723                     com.atlassian.prosemirror:util                  1
# 551724                  org.apache.camel.karaf:camel-asn1                  1
# 551725  org.danilopianini:template-for-kotlin-multipla...                  1
# 551726  org.eclipse.platform:org.eclipse.equinox.launc...                  1
# 551727  io.openliberty.features:io.openliberty.interna...                  1
#
# [551728 rows x 2 columns]

# %%
df_score = pd.merge(df_dependents,df_dependencies, on = 'Artifact', how = 'outer')
df_score.fillna(0, inplace=True)

# %%
df_score
# Out:
#                                                  Artifact  DependentReleases  \
# 0                                             junit:junit          2775545.0
# 1                                     org.slf4j:slf4j-api          1965315.0
# 2                                org.mockito:mockito-core          1716125.0
# 3                            org.scala-lang:scala-library          1578767.0
# 4                                org.assertj:assertj-core          1098573.0
# ...                                                   ...                ...
# 592560  ru.pocketbyte.locolaser:runtime-androidnativea...                0.0
# 592561  co.touchlab.skie:runtime-kotlin-1.9.0-watchosa...                0.0
# 592562                  org.apache.camel.karaf:camel-asn1                0.0
# 592563  org.danilopianini:template-for-kotlin-multipla...                0.0
# 592564  org.eclipse.platform:org.eclipse.equinox.launc...                0.0
#
#         DependentArtifacts  DependenciesCount
# 0                 152993.0                2.0
# 1                  86288.0                2.0
# 2                  49097.0                7.0
# 3                  81074.0                1.0
# 4                  26342.0               39.0
# ...                    ...                ...
# 592560                 0.0                1.0
# 592561                 0.0                1.0
# 592562                 0.0                1.0
# 592563                 0.0                1.0
# 592564                 0.0                1.0
#
# [592565 rows x 4 columns]

# %%
df_score['InstabilityScore'] = df_score['DependenciesCount']/(df_score['DependenciesCount']+df_score['DependentArtifacts'])

# %%
df_score
# Out:
#                                                  Artifact  DependentReleases  \
# 0                                             junit:junit          2775545.0
# 1                                     org.slf4j:slf4j-api          1965315.0
# 2                                org.mockito:mockito-core          1716125.0
# 3                            org.scala-lang:scala-library          1578767.0
# 4                                org.assertj:assertj-core          1098573.0
# ...                                                   ...                ...
# 592560  ru.pocketbyte.locolaser:runtime-androidnativea...                0.0
# 592561  co.touchlab.skie:runtime-kotlin-1.9.0-watchosa...                0.0
# 592562                  org.apache.camel.karaf:camel-asn1                0.0
# 592563  org.danilopianini:template-for-kotlin-multipla...                0.0
# 592564  org.eclipse.platform:org.eclipse.equinox.launc...                0.0
#
#         DependentArtifacts  DependenciesCount  InstabilityScore
# 0                 152993.0                2.0          0.000013
# 1                  86288.0                2.0          0.000023
# 2                  49097.0                7.0          0.000143
# 3                  81074.0                1.0          0.000012
# 4                  26342.0               39.0          0.001478
# ...                    ...                ...               ...
# 592560                 0.0                1.0          1.000000
# 592561                 0.0                1.0          1.000000
# 592562                 0.0                1.0          1.000000
# 592563                 0.0                1.0          1.000000
# 592564                 0.0                1.0          1.000000
#
# [592565 rows x 5 columns]

# %%
#excel_file_path = './CSV/stabilityScore.xlsx'
#df_score.to_excel(excel_file_path, index=False)

# %%
# df after removing artifacts that have stability score of 1
df_filtered = df_score[df_score['InstabilityScore'] != 1]
df_filtered = df_filtered.reset_index(drop=True)

# %%
df_filtered
# Out:
#                                      Artifact  DependentReleases  \
# 0                                 junit:junit          2775545.0
# 1                         org.slf4j:slf4j-api          1965315.0
# 2                    org.mockito:mockito-core          1716125.0
# 3                org.scala-lang:scala-library          1578767.0
# 4                    org.assertj:assertj-core          1098573.0
# ...                                       ...                ...
# 312791       org.webjars.npm:big-sparse-array                1.0
# 312792     org.webjars.npm:quickbit-universal                1.0
# 312793  org.webjars.npm:random-array-iterator                1.0
# 312794          org.webjars.npm:crc-universal                1.0
# 312795                      io.th0rgal:oraxen                1.0
#
#         DependentArtifacts  DependenciesCount  InstabilityScore
# 0                 152993.0                2.0          0.000013
# 1                  86288.0                2.0          0.000023
# 2                  49097.0                7.0          0.000143
# 3                  81074.0                1.0          0.000012
# 4                  26342.0               39.0          0.001478
# ...                    ...                ...               ...
# 312791                 1.0                0.0          0.000000
# 312792                 1.0                0.0          0.000000
# 312793                 1.0                0.0          0.000000
# 312794                 1.0                0.0          0.000000
# 312795                 1.0                0.0          0.000000
#
# [312796 rows x 5 columns]

# %%
sns.histplot(df_filtered['InstabilityScore'], kde=True,bins = 20 ,linewidth=0)
sns.kdeplot(df_filtered['InstabilityScore'], color='blue', linewidth=2)

# Customizing the plot
plt.title('Distribution of Instability Score')
plt.xlabel('Instability Score')
plt.ylabel('Density')
plt.show()

# Explanation of KDE curve:
# A KDE (Kernel Density Estimate) curve is a smooth, continuous line that represents the probability density function 
# of a dataset. It helps to visualize the distribution of data points and is useful for understanding the underlying 
# trends or patterns. In this plot, the KDE curve shows how the stability scores are distributed across different values.

# Calculating the average stability score
avg_stability = df_filtered['InstabilityScore'].mean()

# Creating a new column to categorize scores as 'Above Average' or 'Below Average'
df_filtered['Above_Avg'] = df_filtered['InstabilityScore'] > avg_stability

# Counting values above and below the average
counts = df_filtered['Above_Avg'].value_counts().rename(index={True: 'Above Avg', False: 'Below Avg'})

# Plotting the counts
sns.barplot(x=counts.index, y=counts.values, palette="viridis")

# Customizing the plot
plt.title('Count of Instability Scores Above and Below Average')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_14440\2627620278.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, palette="viridis")

# %%
numerical_columns = ["DependentReleases", "DependentArtifacts", "DependenciesCount", "InstabilityScore"]
correlation_matrix = df_filtered[numerical_columns].corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Matrix")
plt.show()

# %%
sns.set(style='white', font_scale=1.2)

g = sns.JointGrid(data= df_filtered, x='InstabilityScore', y='DependentReleases', xlim=(0, 1), ylim=(0, 300000), height=5)
g = g.plot_joint(sns.regplot, color="xkcd:muted blue")
g = g.plot_marginals(sns.distplot, kde=False, bins=12, color="xkcd:bluey grey")
plt.tight_layout()
# Out:
# C:\Users\divya\anaconda3\envs\test\Lib\site-packages\seaborn\axisgrid.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(self.x, **orient_kw_x, **kwargs)
# C:\Users\divya\anaconda3\envs\test\Lib\site-packages\seaborn\axisgrid.py:1892: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(self.y, **orient_kw_y, **kwargs)

# %%
print(Counter(df_filtered['InstabilityScore']))
# Out:
# Counter({0.0: 40837, 0.5: 21894, 0.6666666666666666: 20686, 0.75: 17743, 0.8: 14546, 0.8333333333333334: 12547, 0.8571428571428571: 10540, 0.875: 8053, 0.6: 7756, 0.3333333333333333: 7431, 0.8888888888888888: 6410, 0.9: 5466, 0.7142857142857143: 5332, 0.9090909090909091: 4971, 0.7777777777777778: 3889, 0.4: 3861, 0.9166666666666666: 3854, 0.25: 3533, 0.5714285714285714: 3276, 0.9230769230769231: 3271, 0.625: 2729, 0.8181818181818182: 2701, 0.9285714285714286: 2547, 0.42857142857142855: 2248, 0.9333333333333333: 2178, 0.2: 2165, 0.7: 2033, 0.8461538461538461: 1886, 0.7272727272727273: 1842, 0.9375: 1800, 0.5555555555555556: 1733, 0.9411764705882353: 1496, 0.8666666666666667: 1465, 0.375: 1407, 0.2857142857142857: 1395, 0.7692307692307693: 1383, 0.6363636363636364: 1321, 0.4444444444444444: 1236, 0.16666666666666666: 1181, 0.7857142857142857: 1150, 0.9444444444444444: 1147, 0.9473684210526315: 1079, 0.8823529411764706: 1028, 0.95: 968, 0.5454545454545454: 943, 0.9545454545454546: 923, 0.6923076923076923: 883, 0.14285714285714285: 805, 0.9523809523809523: 794, 0.8125: 793, 0.5833333333333334: 754, 0.8947368421052632: 745, 0.36363636363636365: 730, 0.45454545454545453: 723, 0.6153846153846154: 696, 0.7333333333333333: 692, 0.3: 671, 0.2222222222222222: 671, 0.8
217391: 211, 0.967741935483871: 211, 0.3125: 209, 0.84: 209, 0.9310344827586207: 209, 0.9705882352941176: 206, 0.9259259259259259: 204, 0.07692307692307693: 198, 0.7727272727272727: 198, 0.782608695652174: 195, 0.5789473684210527: 194, 0.65: 193, 0.3888888888888889: 191, 0.13333333333333333: 186, 0.35294117647058826: 185, 0.29411764705882354: 183, 0.5263157894736842: 180, 0.23529411764705882: 179, 0.3684210526315789: 179, 0.8846153846153846: 177, 0.96875: 174, 0.8928571428571429: 173, 0.9696969696969697: 166, 0.47368421052631576: 165, 0.1875: 162, 0.17647058823529413: 162, 0.2777777777777778: 158, 0.8222222222222222: 158, 0.06666666666666667: 151, 0.7916666666666666: 149, 0.8076923076923077: 147, 0.896551724137931: 147, 0.55: 146, 0.07142857142857142: 143, 0.2631578947368421: 142, 0.5238095238095238: 136, 0.42105263157894735: 134, 0.7083333333333334: 132, 0.76: 130, 0.9354838709677419: 130, 0.6521739130434783: 128, 0.6190476190476191: 127, 0.45: 127, 0.35: 126, 0.5652173913043478: 125, 0.47619047619047616: 124, 0.7391304347826086: 124, 0.9393939393939394: 124, 0.5217391304347826: 123, 0.8518518518518519: 123, 0.43478260869565216: 122, 0.3157894736842105: 121, 0.11764705882352941: 119, 0.8148148148148148: 119, 0.9722222222222222: 119, 0.21052631578947367: 118, 0.9714285714285714: 118, 0.0625: 117, 0.6956521739130435: 117, 0.38095238095238093: 116, 0.15789473684210525: 116, 0.6818181818181818: 114, 0.95348837209302 ...

# %%
sns.histplot(df_score['InstabilityScore'], kde=True, stat = 'density',linewidth=0)
sns.kdeplot(df_score['InstabilityScore'], color='blue', linewidth=2)

# Customizing the plot
plt.title('Distribution of Instability Score')
plt.xlabel('Instability Score')
plt.ylabel('Density')
plt.show()

# Explanation of KDE curve:
# A KDE (Kernel Density Estimate) curve is a smooth, continuous line that represents the probability density function 
# of a dataset. It helps to visualize the distribution of data points and is useful for understanding the underlying 
# trends or patterns. In this plot, the KDE curve shows how the stability scores are distributed across different values.

# Calculating the average stability score
avg_stability = df_score['InstabilityScore'].mean()

# Creating a new column to categorize scores as 'Above Average' or 'Below Average'
df_score['Above_Avg'] = df_score['InstabilityScore'] > avg_stability

# Counting values above and below the average
counts = df_score['Above_Avg'].value_counts().rename(index={True: 'Above Avg', False: 'Below Avg'})

# Plotting the counts
sns.barplot(x=counts.index, y=counts.values, palette="viridis")

# Customizing the plot
plt.title('Count of Instability Scores Above and Below Average')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_14440\1408981541.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, palette="viridis")

# %%
numerical_columns = ["DependentReleases", "DependentArtifacts", "DependenciesCount", "InstabilityScore"]
correlation_matrix = df_score[numerical_columns].corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Matrix")
plt.show()

# %%
avg_stability
# Out:
# 0.7760740176906225

# %%
counts
# Out:
# Above_Avg
# Above Avg    393140
# Below Avg    199425
# Name: count, dtype: int64
