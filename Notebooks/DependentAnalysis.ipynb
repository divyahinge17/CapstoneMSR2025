# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = './CSV/DependentsCounts.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#                                      Artifact  DependentReleases  \
# 0                                 junit:junit            2775545
# 1                         org.slf4j:slf4j-api            1965315
# 2                    org.mockito:mockito-core            1716125
# 3                org.scala-lang:scala-library            1578767
# 4                    org.assertj:assertj-core            1098573
# ...                                       ...                ...
# 312791       org.webjars.npm:big-sparse-array                  1
# 312792     org.webjars.npm:quickbit-universal                  1
# 312793  org.webjars.npm:random-array-iterator                  1
# 312794          org.webjars.npm:crc-universal                  1
# 312795                      io.th0rgal:oraxen                  1
#
#         DependentArtifacts
# 0                   152993
# 1                    86288
# 2                    49097
# 3                    81074
# 4                    26342
# ...

# %%
min_value = df['DependentArtifacts'].min()
max_value = df['DependentArtifacts'].max()
print(f"Min DependentArtifacts: {min_value}, Max DependentArtifacts: {max_value}")

# Define bins based on the data range
bins = list(range(0, max_value + 5000, 5000))  # Adjust bin size based on data range
labels = [f'{i}-{i + 5000}' for i in bins[:-1]]  # Label for each bin

# Categorize the DependentArtifacts into the bins
df['DependentArtifactsRange'] = pd.cut(df['DependentArtifacts'], bins=bins, labels=labels, right=False)

# Count how many artifacts fall into each bin
count_per_range = df['DependentArtifactsRange'].value_counts().sort_index()

# Remove empty bins (if you prefer not to show them)
count_per_range = count_per_range[count_per_range > 0]

# Plotting the bar chart with a logarithmic scale for better visualization
plt.figure(figsize=(12, 6))
count_per_range.plot(kind='bar', color='skyblue')
plt.title('Count of Artifacts by DependentArtifacts Range')
plt.xlabel('DependentArtifacts Range')
plt.ylabel('Count of Artifacts (Log Scale)')
plt.yscale('log')  # Apply log scale to the y-axis
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.grid(True)
plt.show()
# Out:
# Min DependentArtifacts: 1, Max DependentArtifacts: 152993

# %%
count_per_range
# Out:
# DependentArtifactsRange
# 0-5000           312705
# 5000-10000           47
# 10000-15000          19
# 15000-20000           8
# 20000-25000           2
# 25000-30000           6
# 35000-40000           3
# 40000-45000           1
# 45000-50000           2
# 80000-85000           1
# 85000-90000           1
# 150000-155000         1
# Name: count, dtype: int64

# %%
min_value = df['DependentArtifacts'].min()
max_value = 5000
print(f"Min DependentArtifacts: {min_value}, Max DependentArtifacts: {max_value}")

# Define bins based on the data range
bins = list(range(0, max_value + 500, 500))  # Adjust bin size based on data range
labels = [f'{i}-{i + 500}' for i in bins[:-1]]  # Label for each bin

# Categorize the DependentArtifacts into the bins
df['DependentArtifactsRange'] = pd.cut(df['DependentArtifacts'], bins=bins, labels=labels, right=False)

# Count how many artifacts fall into each bin
count_per_range = df['DependentArtifactsRange'].value_counts().sort_index()

# Remove empty bins (if you prefer not to show them)
count_per_range = count_per_range[count_per_range > 0]

# Plotting the bar chart with a logarithmic scale for better visualization
plt.figure(figsize=(12, 6))
count_per_range.plot(kind='bar', color='skyblue')
plt.title('Count of Artifacts by DependentArtifacts Range')
plt.xlabel('DependentArtifacts Range')
plt.ylabel('Count of Artifacts (Log Scale)') 
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.grid(True)
plt.show()
# Out:
# Min DependentArtifacts: 1, Max DependentArtifacts: 5000

# %%
count_per_range
# Out:
# DependentArtifactsRange
# 0-500        311836
# 500-1000        502
# 1000-1500       162
# 1500-2000        72
# 2000-2500        47
# 2500-3000        33
# 3000-3500        17
# 3500-4000        15
# 4000-4500        12
# 4500-5000         9
# Name: count, dtype: int64

# %%
min_value = df['DependentArtifacts'].min()
max_value = 500
print(f"Min DependentArtifacts: {min_value}, Max DependentArtifacts: {max_value}")

# Define bins based on the data range
bins = list(range(0, max_value + 100, 100))  # Adjust bin size based on data range
labels = [f'{i}-{i + 100}' for i in bins[:-1]]  # Label for each bin

# Categorize the DependentArtifacts into the bins
df['DependentArtifactsRange'] = pd.cut(df['DependentArtifacts'], bins=bins, labels=labels, right=False)

# Count how many artifacts fall into each bin
count_per_range = df['DependentArtifactsRange'].value_counts().sort_index()

# Remove empty bins (if you prefer not to show them)
count_per_range = count_per_range[count_per_range > 0]

# Plotting the bar chart with a logarithmic scale for better visualization
plt.figure(figsize=(12, 6))
count_per_range.plot(kind='bar', color='skyblue')
plt.title('Count of Artifacts by DependentArtifacts Range')
plt.xlabel('DependentArtifacts Range')
plt.ylabel('Count of Artifacts (Log Scale)') 
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.grid(True)
plt.show()
# Out:
# Min DependentArtifacts: 1, Max DependentArtifacts: 500

# %%
min_value = df['DependentArtifacts'].min()
max_value = 100
print(f"Min DependentArtifacts: {min_value}, Max DependentArtifacts: {max_value}")

# Define bins based on the data range
bins = list(range(0, max_value + 10, 10))  # Adjust bin size based on data range
labels = [f'{i}-{i + 10}' for i in bins[:-1]]  # Label for each bin

# Categorize the DependentArtifacts into the bins
df['DependentArtifactsRange'] = pd.cut(df['DependentArtifacts'], bins=bins, labels=labels, right=False)

# Count how many artifacts fall into each bin
count_per_range = df['DependentArtifactsRange'].value_counts().sort_index()

# Remove empty bins (if you prefer not to show them)
count_per_range = count_per_range[count_per_range > 0]

# Plotting the bar chart with a logarithmic scale for better visualization
plt.figure(figsize=(12, 6))
count_per_range.plot(kind='bar', color='skyblue')
plt.title('Count of Artifacts by DependentArtifacts Range')
plt.xlabel('DependentArtifacts Range')
plt.ylabel('Count of Artifacts (Log Scale)') 
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.grid(True)
plt.show()
# Out:
# Min DependentArtifacts: 1, Max DependentArtifacts: 100
