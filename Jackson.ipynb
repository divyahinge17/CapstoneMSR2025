# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
file_path = 'C:/Users/divya/Projects/Capstone/QueryExports/0010_jackson-databind_dependents_releaseWise.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#                                          releaseID targetVersion  \
# 0    "com.fasterxml.jackson.core:jackson-databind"   "2.0.0-RC1"
# 1    "com.fasterxml.jackson.core:jackson-databind"   "2.0.0-RC2"
# 2    "com.fasterxml.jackson.core:jackson-databind"   "2.0.0-RC3"
# 3    "com.fasterxml.jackson.core:jackson-databind"       "2.0.0"
# 4    "com.fasterxml.jackson.core:jackson-databind"       "2.0.1"
# ..                                             ...           ...
# 193  "com.fasterxml.jackson.core:jackson-databind"      "2.16.2"
# 194  "com.fasterxml.jackson.core:jackson-databind"      "2.17.0"
# 195  "com.fasterxml.jackson.core:jackson-databind"    "2.12.7.2"
# 196  "com.fasterxml.jackson.core:jackson-databind"      "2.17.1"
# 197  "com.fasterxml.jackson.core:jackson-databind"      "2.17.2"
#
#      dependentCount             releaseDate  releaseTimestamp
# 0                15  "2012-02-19T08:05:21Z"     1329638721000
# 1                15  "2012-03-06T07:02:08Z"     1331017328000
# 2                14  "2012-03-23T00:19:13Z"     1332461953000
# 3               558  "2012-03-25T19:11:24Z"     1332702684000
# 4               196  "2012-04-24T02:17:59Z"     1335233879000
# ..              ...                     ...               ...
# 193            1472  "2024-03-09T18:54:12Z"     1710010452000
# 194            7105  "2024-03-12T21:53:32Z"     1710280412000
# 195             166  "2024-05-02T20:10:51Z"     1714680651000
# 196            7273  "2024-05-05T02:07:56Z"     1714874876000
# 197            5185  "2024-07-05T17:15:54Z"     1720199754000
#
# [198 rows x 5 columns]

# %%
df['releaseDate'] = df['releaseDate'].str.strip('"')
df['releaseDate'] = pd.to_datetime(df['releaseDate'], format='%Y-%m-%dT%H:%M:%SZ')
df['year'] = df['releaseDate'].dt.year
dependents_data = df[['year','dependentCount']]

# %%
dependents_data
# Out:
#      year  dependentCount
# 0    2012              15
# 1    2012              15
# 2    2012              14
# 3    2012             558
# 4    2012             196
# ..    ...             ...
# 193  2024            1472
# 194  2024            7105
# 195  2024             166
# 196  2024            7273
# 197  2024            5185
#
# [198 rows x 2 columns]

# %%
yearly_data = dependents_data.groupby('year')[['dependentCount']].sum().reset_index()

print(yearly_data)
# Out:
#     year  dependentCount
# 0   2012            2718
# 1   2013            7412
# 2   2014           15445
# 3   2015           24376
# 4   2016           35720
# 5   2017           37059
# 6   2018           62726
# 7   2019          104302
# 8   2020          157337
# 9   2021          100090
# 10  2022          138360
# 11  2023          136039
# 12  2024           35106

# %%
plt.figure(figsize = (12,6))
plt.plot(yearly_data['year'],yearly_data['dependentCount'], marker='o', label='Added Dependencies', color='blue')

plt.title('Dependents Count')
plt.xlabel('Year')
plt.ylabel('Number of Dependents')
plt.legend()
plt.grid(True)
plt.show()

# %%
df['rhythm'] = 0
for i in range(0, len(df)-1):
    df.at[i,'rhythm'] = (df.at[i+1,'releaseDate'] - df.at[i, 'releaseDate']).days

# %%
rhythm_data = df[['year','rhythm']]

# %%
rhythm_data
# Out:
#      year  rhythm
# 0    2012      15
# 1    2012      16
# 2    2012       2
# 3    2012      29
# 4    2012      20
# ..    ...     ...
# 193  2024       3
# 194  2024      50
# 195  2024       2
# 196  2024      61
# 197  2024       0
#
# [198 rows x 2 columns]

# %%
rhythm_data = rhythm_data.groupby('year')[['rhythm']].sum().reset_index()

print(rhythm_data)
# Out:
#     year  rhythm
# 0   2012     328
# 1   2013     401
# 2   2014     298
# 3   2015     360
# 4   2016     360
# 5   2017     370
# 6   2018     473
# 7   2019     226
# 8   2020     362
# 9   2021     417
# 10  2022     316
# 11  2023     383
# 12  2024     138

# %%
plt.figure(figsize = (12,6))
plt.plot(rhythm_data['year'],rhythm_data['rhythm'], marker='o', label='Rhythm', color='green')

plt.title('Rhythm')
plt.xlabel('Year')
plt.ylabel('Rhythm')
plt.legend()
plt.grid(True)
plt.show()

# %%
rhythm_df = pd.DataFrame()
rhythm_df['releaseDate'] = df['releaseDate'].dt.strftime('%Y-%m')
rhythm_df['rhythm'] = df ['rhythm']

# %%
rhythm_df
# Out:
#     releaseDate  rhythm
# 0       2012-02      15
# 1       2012-03      16
# 2       2012-03       2
# 3       2012-03      29
# 4       2012-04      20
# ..          ...     ...
# 193     2024-03       3
# 194     2024-03      50
# 195     2024-05       2
# 196     2024-05      61
# 197     2024-07       0
#
# [198 rows x 2 columns]

# %%
rhythm_df = rhythm_df.groupby('releaseDate')[['rhythm']].sum().reset_index()

# %%
rhythm_df
# Out:
#     releaseDate  rhythm
# 0       2012-02      15
# 1       2012-03      47
# 2       2012-04      20
# 3       2012-05      43
# 4       2012-06      30
# ..          ...     ...
# 102     2023-12      53
# 103     2024-02      22
# 104     2024-03      53
# 105     2024-05      63
# 106     2024-07       0
#
# [107 rows x 2 columns]

# %%
date_range = pd.date_range(start='2019-01', end=rhythm_df['releaseDate'].max(), freq='3M')

fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(rhythm_df['releaseDate'], rhythm_df['rhythm'], marker='o', label='Rhythm', color='red')

ax.set_title('Rhythm')
ax.set_xlabel('Year')
ax.set_ylabel('Rhythm')
ax.legend()
ax.grid(True)

ax.set_xticks(date_range) 
ax.xaxis.set_major_locator(mdates.MonthLocator(bymonthday=1, interval=3)) 
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m')) 

plt.xticks(rotation=90)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\test\Lib\site-packages\matplotlib\axis.py:1769, in Axis.convert_units(self, x)
#    1768 try:
# -> 1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
#
# File ~\anaconda3\envs\test\Lib\site-packages\matplotlib\category.py:57, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
# ---> 57 unit.update(values)
#      58 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File ~\anaconda3\envs\test\Lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#
# File ~\anaconda3\envs\test\Lib\site-packages\matplotlib\_api\__init__.py:91, in check_isinstance(types, **kwargs)
#      90     names.append("None")
# ---> 91 raise TypeError(
#      92     "{!r} must be an instance of {}, not a {}".format(
#      93         k,
#      94         ", ".join(names[:-1]) + " or " + names[-1]
#      95         if len(names) > 1 else names[0],
#      96         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a pandas._libs.tslibs.timestamps.Timestamp
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[57], line 12
#       9 ax.legend()
#      10 ax.grid(True)
# ---> 12 ax.set_xticks(date_range)
#      13 ax.xaxis.set_major_locator(mdates.MonthLocator(bymonthday=1, interval=3))
#      14 ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
#
# File ~\anaconda3\envs\test\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\envs\test\Lib\site-packages\matplotlib\axis.py:2138, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2133     first_key = next(iter(kwargs))
#    2134     raise ValueError(
#    2135         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#    2136         "other than 'minor' modify the text labels and can only be used if "
#    2137         "'labels' are passed as well.")
# -> 2138 result = self._set_tick_locations(ticks, minor=minor)
#    2139 if labels is not None:
#    2140     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~\anaconda3\envs\test\Lib\site-packages\matplotlib\axis.py:2077, in Axis._set_tick_locations(self, ticks, minor)
#    2073 def _set_tick_locations(self, ticks, *, minor=False):
#    2074     # see docstring of set_ticks
#    2075
#    2076     # XXX if the user changes units, the information will be lost here
# -> 2077     ticks = self.convert_units(ticks)
#    2078     locator = mticker.FixedLocator(ticks)  # validate ticks early.
#    2079     if len(ticks):
#
# File ~\anaconda3\envs\test\Lib\site-packages\matplotlib\axis.py:1771, in Axis.convert_units(self, x)
#    1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
# -> 1771     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1772                                  f'units: {x!r}') from e
#    1773 return ret
#
# ConversionError: Failed to convert value(s) to axis units: DatetimeIndex(['2019-01-31', '2019-04-30', '2019-07-31', '2019-10-31',
#                '2020-01-31', '2020-04-30', '2020-07-31', '2020-10-31',
#                '2021-01-31', '2021-04-30', '2021-07-31', '2021-10-31',
#                '2022-01-31', '2022-04-30', '2022-07-31', '2022-10-31',
#                '2023-01-31', '2023-04-30', '2023-07-31', '2023-10-31',
#                '2024-01-31', '2024-04-30'],
#               dtype='datetime64[ns]', freq='3M')

# %%
# Ensure 'releaseDate' is in datetime format
rhythm_df['releaseDate'] = pd.to_datetime(rhythm_df['releaseDate'])

# Create date range with 3-month intervals
start_date = '2019-01'
end_date = rhythm_df['releaseDate'].max()
date_range = pd.date_range(start=start_date, end=end_date, freq='3M').to_pydatetime()

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(rhythm_df['releaseDate'], rhythm_df['rhythm'], marker='o', label='Rhythm', color='red')

# Setting title and labels
ax.set_title('Rhythm')
ax.set_xlabel('Year')
ax.set_ylabel('Rhythm')
ax.legend()
ax.grid(True)

# Set x-ticks at 3-month intervals and format
ax.set_xticks(date_range)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))  # Locator for 3-month intervals
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Format as 'YYYY-MM'

plt.xticks(rotation=90)
plt.show()
